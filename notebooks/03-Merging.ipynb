# %% [markdown]
# # Merging Data
#
# Combining and reshaping data from multiple sources
#
# For this module, we will be exploring the techniques for combining and reshaping data from multiple sources. You will learn about:
#
# * Combining data using pandas library
# * Validating Merges
# * Debugging Chains
# * Exporting to Excel

# %%
import numpy as np
import pandas as pd
import polars as pl
import zipfile

# %%
# https://www.kaggle.com/datasets/dgomonov/new-york-city-airbnb-open-data?resource=download
with zipfile.ZipFile('data/AB_NYC_2019.csv.zip') as zip:
  print(zip.namelist())
# Out:
# ['AB_NYC_2019.csv']

# %%
ab = pd.read_csv('data/AB_NYC_2019.csv.zip',
                 dtype_backend='pyarrow',
                 engine='pyarrow')
ab.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room    149               1                  9  2018-10-19
# 1  Entire home/apt    225               1                 45  2019-05-21
# 2     Private room    150               3                  0        <NA>
# 3  Entire home/apt     89               1                270  2019-07-05
# 4  Entire home/apt     80              10                  9  2018-11-19
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.21                               6               365
# 1               0.38                               2               355
# 2               <NA>                               1               365
# 3               4.64                               1               194
# 4                0.1                               1                 0

# %%
ab_pl = pl.read_csv(zipfile.ZipFile("data/AB_NYC_2019.csv.zip").read("AB_NYC_2019.csv"))

# %%
temps = pd.read_csv('data/nyc-ab-temp.csv',
                    index_col=0,
                    dtype_backend='pyarrow',
                    engine='pyarrow')

# %%
temps_pl = (pl
            .scan_csv("data/nyc-ab-temp.csv")
            .drop("")
            .collect()
            )

# %%
temps.head()
# Out:
#         lat       lon  temp
#
# 0  40.64749 -73.97237  72.0
# 1  40.75362 -73.98377  57.0
# 2  40.80902 -73.94190  76.0
# 3  40.68514 -73.95976  24.0
# 4  40.79851 -73.94399  27.0

# %%
temps_pl.head()
# Out:
# shape: (5, 3)
# ┌──────────┬───────────┬──────┐
# │ lat      ┆ lon       ┆ temp │
# │ ---      ┆ ---       ┆ ---  │
# │ f64      ┆ f64       ┆ f64  │
# ╞══════════╪═══════════╪══════╡
# │ 40.64749 ┆ -73.97237 ┆ 72.0 │
# │ 40.75362 ┆ -73.98377 ┆ 57.0 │
# │ 40.80902 ┆ -73.9419  ┆ 76.0 │
# │ 40.68514 ┆ -73.95976 ┆ 24.0 │
# │ 40.79851 ┆ -73.94399 ┆ 27.0 │
# └──────────┴───────────┴──────┘

# %% [markdown]
# ## Merging

# %%
# Error expected here. We're working to fix it in the next few cells.
# (ab
#  .merge(temps)
# )

# %%
(ab.columns.intersection(temps.columns))
# Out:
# Index([], dtype='object')

# %%
(set(ab_pl.columns).intersection(temps_pl.columns))
# Out:
# set()

# %%
ab.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
ab_pl.columns
# Out:
# ['id',
#  'name',
#  'host_id',
#  'host_name',
#  'neighbourhood_group',
#  'neighbourhood',
#  'latitude',
#  'longitude',
#  'room_type',
#  'price',
#  'minimum_nights',
#  'number_of_reviews',
#  'last_review',
#  'reviews_per_month',
#  'calculated_host_listings_count',
#  'availability_365']

# %%
temps.columns
# Out:
# Index(['lat', 'lon', 'temp'], dtype='object')

# %%
temps_pl.columns
# Out:
# ['lat', 'lon', 'temp']

# %%
temps = temps.rename(columns=dict(lat="latitude", lon="longitude"))

# %%
(ab
 .merge(temps, on=["latitude", "longitude"])
 .sample(10)
)
# Out:
#              id                                               name    host_id  \
# 11269   8733620                Lg private room minutes from subway    3571821
# 25973  20738759                        Sun-Filled Cobble Hill Loft    2687071
# 31467  24477757  Large Private Room in a Magnificent Penthouse ...  169382341
# 7068    5091056                  Comfy Bedroom quite neighborhood    26301893
# 3322    1983188                   1BR near Columbia / Central Park    1521508
# 33116  26126570           Two bedroom apartment with all amenities     673215
# 5489    3970701      Beautiful Private Room in Newly Renovated Apt   20278196
# 12510   9613541                             Open Room for December   49738780
# 47582  35809258  Cozy and Modern 3BR for upto 6 ppl - 4min to m...  269220629
# 30455  23559016               Lovely room in heart of Williamsburg  173021064
#
#             host_name neighbourhood_group       neighbourhood  latitude  \
# 11269  Andy & Friends            Brooklyn  Bedford-Stuyvesant  40.69053
# 25973            Lily            Brooklyn    Brooklyn Heights  40.69040
# 31467           Tomás           Manhattan        East Village  40.72200
# 7068           Claude              Queens        Forest Hills  40.71158
# 3322             Jose           Manhattan     Upper West Side  40.79859
# 33116    Jessica Rose           Manhattan              Harlem  40.82299
# 5489        Stephanie            Brooklyn       East Flatbush  40.66303
# 12510           Katie              Queens             Astoria  40.77211
# 47582       Isidro M.            Brooklyn       Crown Heights  40.67671
# 30455           Katie            Brooklyn        Williamsburg  40.71081
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# 11269  -73.95632     Private room     45               5                 32
# 25973  -73.99376  Entire home/apt    135               3                 21
# 31467  -73.98396     Private room     89               5                 11
# 7068   -73.85273     Private room     80               1                 12
# 3322   -73.96078     Private room     80               3                 38
# 33116  -73.95461  Entire home/apt    200               5                  0
# 5489   -73.92526     Private room     60               2                  6
# 12510  -73.92055     Private room    100               1                  0
# 47582  -73.93991  Entire home/apt    169               4                  0
# 30455  -73.94965     Private room     75               2                  2
#
#       last_review  reviews_per_month  calculated_host_listings_count  \
# 11269  2017-12-26                0.7                               4
# 25973  2019-05-05               0.95                               1
# 31467  2019-06-27               0.84                               2
# 7068   2019-01-03               0.35                               1
# 3322   2019-06-26               0.59                               1
# 33116        <NA>               <NA>                               2
# 5489   2019-02-03               0.26                               3
# 12510        <NA>               <NA>                               1
# 47582        <NA>               <NA>                               1
# 30455  2018-04-22               0.13                               2
#
#        availability_365  temp
# 11269                 0  86.0
# 25973                15  48.0
# 31467                76  78.0
# 7068                 59  58.0
# 3322                344  71.0
# 33116                39  37.0
# 5489                326  71.0
# 12510                 0  76.0
# 47582               324  50.0
# 30455                 7  48.0

# %%
temps_pl = temps_pl.rename(dict(lat="latitude", lon="longitude"))

# %%
(ab_pl
 .join(temps_pl, on=["latitude", "longitude"])
 .sample(10)
 )
# Out:
# shape: (10, 17)
# ┌──────────┬─────────────┬───────────┬───────────┬───┬────────────┬────────────┬────────────┬──────┐
# │ id       ┆ name        ┆ host_id   ┆ host_name ┆ … ┆ reviews_pe ┆ calculated ┆ availabili ┆ temp │
# │ ---      ┆ ---         ┆ ---       ┆ ---       ┆   ┆ r_month    ┆ _host_list ┆ ty_365     ┆ ---  │
# │ i64      ┆ str         ┆ i64       ┆ str       ┆   ┆ ---        ┆ ings_count ┆ ---        ┆ f64  │
# │          ┆             ┆           ┆           ┆   ┆ f64        ┆ ---        ┆ i64        ┆      │
# │          ┆             ┆           ┆           ┆   ┆            ┆ i64        ┆            ┆      │
# ╞══════════╪═════════════╪═══════════╪═══════════╪═══╪════════════╪════════════╪════════════╪══════╡
# │ 15016999 ┆ Crown       ┆ 94782931  ┆ Joe       ┆ … ┆ 0.21       ┆ 1          ┆ 6          ┆ 76.0 │
# │          ┆ Heights     ┆           ┆           ┆   ┆            ┆            ┆            ┆      │
# │          ┆ 1-Bedroom   ┆           ┆           ┆   ┆            ┆            ┆            ┆      │
# │          ┆ Near Par…   ┆           ┆           ┆   ┆            ┆            ┆            ┆      │
# │ 18066733 ┆ 5br Duplex. ┆ 117492425 ┆ Dine      ┆ … ┆ 0.16       ┆ 6          ┆ 230        ┆ 27.0 │
# │          ┆ @ Ferry!    ┆           ┆           ┆   ┆            ┆            ┆            ┆      │
# │          ┆ Water&City… ┆           ┆           ┆   ┆            ┆            ┆            ┆      │
# │ 1439162  ┆ Cozy &      ┆ 7460181   ┆ Geraldine ┆ … ┆ 2.89       ┆ 1          ┆ 206        ┆ 29.0 │
# │          ┆ Private 1   ┆           ┆           ┆   ┆            ┆            ┆            ┆      │
# │          ┆ Bedroom     ┆           ┆           ┆   ┆            ┆            ┆            ┆      │
# │          ┆ Garden …    ┆           ┆           ┆   ┆            ┆            ┆            ┆      │
# │ 167013   ┆ Spacious    ┆ 306605    ┆ Daniel    ┆ … ┆ 0.04       ┆ 2          ┆ 76         ┆ 43.0 │
# │          ┆ modern      ┆           ┆           ┆   ┆            ┆            ┆            ┆      │
# │          ┆ studio      ┆           ┆           ┆   ┆            ┆            ┆            ┆      │
# │          ┆ apartment…  ┆           ┆           ┆   ┆            ┆            ┆            ┆      │
# │ …        ┆ …           ┆ …         ┆ …         ┆ … ┆ …          ┆ …          ┆ …          ┆ …    │
# │ 24159289 ┆ Great View  ┆ 41366374  ┆ Jiangyang ┆ … ┆ null       ┆ 1          ┆ 0          ┆ 28.0 │
# │          ┆ of New York ┆           ┆           ┆   ┆            ┆            ┆            ┆      │
# │          ┆ city        ┆           ┆           ┆   ┆            ┆            ┆            ┆      │
# │ 19550594 ┆ Williamsbur ┆ 19631496  ┆ The       ┆ … ┆ 3.49       ┆ 2          ┆ 278        ┆ 52.0 │
# │          ┆ g Oasis     ┆           ┆           ┆   ┆            ┆            ┆            ┆      │
# │          ┆ with Palm   ┆           ┆           ┆   ┆            ┆            ┆            ┆      │
# │          ┆ Tre…        ┆           ┆           ┆   ┆            ┆            ┆            ┆      │
# │ 11032957 ┆ Glorious    ┆ 57254931  ┆ Courtney  ┆ … ┆ 1.66       ┆ 1          ┆ 0          ┆ 75.0 │
# │          ┆ brownstone  ┆           ┆           ┆   ┆            ┆            ┆            ┆      │
# │          ┆ apt w/      ┆           ┆           ┆   ┆            ┆            ┆            ┆      │
# │          ┆ outdo…      ┆           ┆           ┆   ┆            ┆            ┆            ┆      │
# │ 4724943  ┆ Charming    ┆ 24403405  ┆ Naomi     ┆ … ┆ 0.02       ┆ 1          ┆ 0          ┆ 70.0 │
# │          ┆ 1BD Across  ┆           ┆           ┆   ┆            ┆            ┆            ┆      │
# │          ┆ from Park   ┆           ┆           ┆   ┆            ┆            ┆            ┆      │
# └──────────┴─────────────┴───────────┴───────────┴───┴────────────┴────────────┴────────────┴──────┘

# %% [markdown]
# ## Validating Merges

# %%
left = pd.DataFrame({'name': ['Ravi', 'Jose', 'Jose'],
                    'pet': ['Dog', 'Cat', 'Dog']})
right = pd.DataFrame({'name': ['Ravi', 'Jose', 'Sally'],
                      'age': [10, 17, 5]})

# %%
display(left)
display(right)
# Out:
#    name  pet
# 0  Ravi  Dog
# 1  Jose  Cat
# 2  Jose  Dog
#     name  age
# 0   Ravi   10
# 1   Jose   17
# 2  Sally    5

# %%
left.merge(right, how='inner')
# Out:
#    name  pet  age
# 0  Ravi  Dog   10
# 1  Jose  Cat   17
# 2  Jose  Dog   17

# %%
left.merge(right, how='left')
# Out:
#    name  pet  age
# 0  Ravi  Dog   10
# 1  Jose  Cat   17
# 2  Jose  Dog   17

# %%
left.merge(right, how='right')
# Out:
#     name  pet  age
# 0   Ravi  Dog   10
# 1   Jose  Cat   17
# 2   Jose  Dog   17
# 3  Sally  NaN    5

# %%
left.merge(right, how='outer')
# Out:
#     name  pet  age
# 0   Ravi  Dog   10
# 1   Jose  Cat   17
# 2   Jose  Dog   17
# 3  Sally  NaN    5

# %%
left.merge(right, how='cross')
# Out:
#   name_x  pet name_y  age
# 0   Ravi  Dog   Ravi   10
# 1   Ravi  Dog   Jose   17
# 2   Ravi  Dog  Sally    5
# 3   Jose  Cat   Ravi   10
# 4   Jose  Cat   Jose   17
# 5   Jose  Cat  Sally    5
# 6   Jose  Dog   Ravi   10
# 7   Jose  Dog   Jose   17
# 8   Jose  Dog  Sally    5

# %%
left
# Out:
#    name  pet
# 0  Ravi  Dog
# 1  Jose  Cat
# 2  Jose  Dog

# %%
# left.merge(right, how='inner', validate='1:1')

# %%
left.merge(right, how='inner', validate='m:1')
# Out:
#    name  pet  age
# 0  Ravi  Dog   10
# 1  Jose  Cat   17
# 2  Jose  Dog   17

# %% [markdown]
# ## Debugging Trick

# %%
def limit(df:pd.DataFrame, n_rows:int, n_cols:int) -> pd.DataFrame:
  return df.iloc[:n_rows, :n_cols]

(ab
 .pipe(limit, n_rows=3, n_cols=6)
)
# Out:
#      id                                 name  host_id  host_name  \
# 0  2539   Clean & quiet apt home by the park     2787       John
# 1  2595                Skylit Midtown Castle     2845   Jennifer
# 2  3647  THE VILLAGE OF HARLEM....NEW YORK !     4632  Elisabeth
#
#   neighbourhood_group neighbourhood
# 0            Brooklyn    Kensington
# 1           Manhattan       Midtown
# 2           Manhattan        Harlem

# %%
def limit(df:pl.DataFrame, n_rows:int, n_cols:int):
    return df[:n_rows, :n_cols]


(ab_pl
 .pipe(limit, n_rows=3, n_cols=6)
)
# Out:
# shape: (3, 6)
# ┌──────┬───────────────────────────────┬─────────┬───────────┬─────────────────────┬───────────────┐
# │ id   ┆ name                          ┆ host_id ┆ host_name ┆ neighbourhood_group ┆ neighbourhood │
# │ ---  ┆ ---                           ┆ ---     ┆ ---       ┆ ---                 ┆ ---           │
# │ i64  ┆ str                           ┆ i64     ┆ str       ┆ str                 ┆ str           │
# ╞══════╪═══════════════════════════════╪═════════╪═══════════╪═════════════════════╪═══════════════╡
# │ 2539 ┆ Clean & quiet apt home by the ┆ 2787    ┆ John      ┆ Brooklyn            ┆ Kensington    │
# │      ┆ pa…                           ┆         ┆           ┆                     ┆               │
# │ 2595 ┆ Skylit Midtown Castle         ┆ 2845    ┆ Jennifer  ┆ Manhattan           ┆ Midtown       │
# │ 3647 ┆ THE VILLAGE OF HARLEM....NEW  ┆ 4632    ┆ Elisabeth ┆ Manhattan           ┆ Harlem        │
# │      ┆ YOR…                          ┆         ┆           ┆                     ┆               │
# └──────┴───────────────────────────────┴─────────┴───────────┴─────────────────────┴───────────────┘

# %%
# add debug to helpers
def debug(df:pd.DataFrame, extra:str='') -> pd.DataFrame:
  print(f'{extra} {df.shape=}')
  return df

(ab
 .pipe(debug, extra='before')
 .merge(temps, on=['latitude', 'longitude'])
 .pipe(debug, extra='after') 
)
# Out:
# before df.shape=(48895, 16)
# after df.shape=(48895, 17)
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
#            host_name neighbourhood_group       neighbourhood  latitude  \
# 0               John            Brooklyn          Kensington  40.64749
# 1           Jennifer           Manhattan             Midtown  40.75362
# 2          Elisabeth           Manhattan              Harlem  40.80902
# 3        LisaRoxanne            Brooklyn        Clinton Hill  40.68514
# 4              Laura           Manhattan         East Harlem  40.79851
# ...              ...                 ...                 ...       ...
# 48890        Sabrina            Brooklyn  Bedford-Stuyvesant  40.67853
# 48891        Marisol            Brooklyn            Bushwick  40.70184
# 48892  Ilgar & Aysel           Manhattan              Harlem  40.81475
# 48893            Taz           Manhattan      Hell's Kitchen  40.75751
# 48894     Christophe           Manhattan      Hell's Kitchen  40.76404
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# 0      -73.97237     Private room    149               1                  9
# 1      -73.98377  Entire home/apt    225               1                 45
# 2      -73.94190     Private room    150               3                  0
# 3      -73.95976  Entire home/apt     89               1                270
# 4      -73.94399  Entire home/apt     80              10                  9
# ...          ...              ...    ...             ...                ...
# 48890  -73.94995     Private room     70               2                  0
# 48891  -73.93317     Private room     40               4                  0
# 48892  -73.94867  Entire home/apt    115              10                  0
# 48893  -73.99112      Shared room     55               1                  0
# 48894  -73.98933     Private room     90               7                  0
#
#       last_review  reviews_per_month  calculated_host_listings_count  \
# 0      2018-10-19               0.21                               6
# 1      2019-05-21               0.38                               2
# 2            <NA>               <NA>                               1
# 3      2019-07-05               4.64                               1
# 4      2018-11-19                0.1                               1
# ...           ...                ...                             ...
# 48890        <NA>               <NA>                               2
# 48891        <NA>               <NA>                               2
# 48892        <NA>               <NA>                               1
# 48893        <NA>               <NA>                               6
# 48894        <NA>               <NA>                               1
#
#        availability_365  temp
# 0                   365  72.0
# 1                   355  57.0
# 2                   365  76.0
# 3                   194  24.0
# 4                     0  27.0
# ...                 ...   ...
# 48890                 9  76.0
# 48891                36  71.0
# 48892                27  44.0
# 48893                 2  73.0
# 48894                23  76.0
#
# [48895 rows x 17 columns]

# %%
def debug(df:pl.DataFrame, extra:str=""):
    print(f"{extra} {df.shape=}")
    return df


(ab_pl
 .pipe(debug, extra="before")
 .join(temps_pl, on=["latitude", "longitude"])
 .pipe(debug, extra="after")
)
# Out:
# before df.shape=(48895, 16)
# after df.shape=(48895, 17)
# shape: (48_895, 17)
# ┌──────────┬─────────────┬──────────┬────────────┬───┬────────────┬────────────┬────────────┬──────┐
# │ id       ┆ name        ┆ host_id  ┆ host_name  ┆ … ┆ reviews_pe ┆ calculated ┆ availabili ┆ temp │
# │ ---      ┆ ---         ┆ ---      ┆ ---        ┆   ┆ r_month    ┆ _host_list ┆ ty_365     ┆ ---  │
# │ i64      ┆ str         ┆ i64      ┆ str        ┆   ┆ ---        ┆ ings_count ┆ ---        ┆ f64  │
# │          ┆             ┆          ┆            ┆   ┆ f64        ┆ ---        ┆ i64        ┆      │
# │          ┆             ┆          ┆            ┆   ┆            ┆ i64        ┆            ┆      │
# ╞══════════╪═════════════╪══════════╪════════════╪═══╪════════════╪════════════╪════════════╪══════╡
# │ 2539     ┆ Clean &     ┆ 2787     ┆ John       ┆ … ┆ 0.21       ┆ 6          ┆ 365        ┆ 72.0 │
# │          ┆ quiet apt   ┆          ┆            ┆   ┆            ┆            ┆            ┆      │
# │          ┆ home by the ┆          ┆            ┆   ┆            ┆            ┆            ┆      │
# │          ┆ pa…         ┆          ┆            ┆   ┆            ┆            ┆            ┆      │
# │ 2595     ┆ Skylit      ┆ 2845     ┆ Jennifer   ┆ … ┆ 0.38       ┆ 2          ┆ 355        ┆ 57.0 │
# │          ┆ Midtown     ┆          ┆            ┆   ┆            ┆            ┆            ┆      │
# │          ┆ Castle      ┆          ┆            ┆   ┆            ┆            ┆            ┆      │
# │ 3647     ┆ THE VILLAGE ┆ 4632     ┆ Elisabeth  ┆ … ┆ null       ┆ 1          ┆ 365        ┆ 76.0 │
# │          ┆ OF HARLEM.. ┆          ┆            ┆   ┆            ┆            ┆            ┆      │
# │          ┆ ..NEW YOR…  ┆          ┆            ┆   ┆            ┆            ┆            ┆      │
# │ 3831     ┆ Cozy Entire ┆ 4869     ┆ LisaRoxann ┆ … ┆ 4.64       ┆ 1          ┆ 194        ┆ 24.0 │
# │          ┆ Floor of    ┆          ┆ e          ┆   ┆            ┆            ┆            ┆      │
# │          ┆ Brownstone  ┆          ┆            ┆   ┆            ┆            ┆            ┆      │
# │ …        ┆ …           ┆ …        ┆ …          ┆ … ┆ …          ┆ …          ┆ …          ┆ …    │
# │ 36485057 ┆ Affordable  ┆ 6570630  ┆ Marisol    ┆ … ┆ null       ┆ 2          ┆ 36         ┆ 71.0 │
# │          ┆ room in Bus ┆          ┆            ┆   ┆            ┆            ┆            ┆      │
# │          ┆ hwick/East… ┆          ┆            ┆   ┆            ┆            ┆            ┆      │
# │ 36485431 ┆ Sunny       ┆ 23492952 ┆ Ilgar &    ┆ … ┆ null       ┆ 1          ┆ 27         ┆ 44.0 │
# │          ┆ Studio at   ┆          ┆ Aysel      ┆   ┆            ┆            ┆            ┆      │
# │          ┆ Historical  ┆          ┆            ┆   ┆            ┆            ┆            ┆      │
# │          ┆ Neigh…      ┆          ┆            ┆   ┆            ┆            ┆            ┆      │
# │ 36485609 ┆ 43rd St.    ┆ 30985759 ┆ Taz        ┆ … ┆ null       ┆ 6          ┆ 2          ┆ 73.0 │
# │          ┆ Time        ┆          ┆            ┆   ┆            ┆            ┆            ┆      │
# │          ┆ Square-cozy ┆          ┆            ┆   ┆            ┆            ┆            ┆      │
# │          ┆ single…     ┆          ┆            ┆   ┆            ┆            ┆            ┆      │
# │ 36487245 ┆ Trendy      ┆ 68119814 ┆ Christophe ┆ … ┆ null       ┆ 1          ┆ 23         ┆ 76.0 │
# │          ┆ duplex in   ┆          ┆            ┆   ┆            ┆            ┆            ┆      │
# │          ┆ the very    ┆          ┆            ┆   ┆            ┆            ┆            ┆      │
# │          ┆ heart …     ┆          ┆            ┆   ┆            ┆            ┆            ┆      │
# └──────────┴─────────────┴──────────┴────────────┴───┴────────────┴────────────┴────────────┴──────┘

# %%
(ab
 .pipe(debug, extra='before')
 .merge(temps, on=['latitude', 'longitude'])
 .pipe(debug, extra='after') 
 .groupby('neighbourhood_group')
 .mean(numeric_only = True)
 .pipe(debug, extra='summary') 
)
# Out:
# before df.shape=(48895, 16)
# after df.shape=(48895, 17)
# summary df.shape=(5, 11)
#                                id       host_id   latitude  longitude  \
# neighbourhood_group
# Bronx                2.273492e+07  1.056099e+08  40.848305 -73.884552
# Brooklyn             1.825685e+07  5.671526e+07  40.685036 -73.951190
# Manhattan            1.877494e+07  6.783062e+07  40.765062 -73.974607
# Queens               2.175500e+07  9.615680e+07  40.731531 -73.872775
# Staten Island        2.159747e+07  9.853360e+07  40.610225 -74.105805
#
#                           price  minimum_nights  number_of_reviews  \
# neighbourhood_group
# Bronx                 87.496792        4.560953          26.004583
# Brooklyn             124.383207        6.056556          24.202845
# Manhattan            196.875814        8.579151          20.985596
# Queens                99.517649        5.181433          27.700318
# Staten Island        114.812332        4.831099          30.941019
#
#                      reviews_per_month  calculated_host_listings_count  \
# neighbourhood_group
# Bronx                         1.837831                        2.233731
# Brooklyn                      1.283212                        2.284371
# Manhattan                     1.272131                       12.791330
# Queens                        1.941200                        4.060184
# Staten Island                 1.872580                        2.319035
#
#                      availability_365       temp
# neighbourhood_group
# Bronx                      165.758937  55.450459
# Brooklyn                   100.232292  56.169537
# Manhattan                  111.979410  55.908629
# Queens                     144.451818  55.913604
# Staten Island              199.678284  55.873995

# %%
(ab_pl
 .pipe(debug, extra="before")
 .join(temps_pl, on=["latitude", "longitude"])
 .pipe(debug, extra="after")
 .group_by("neighbourhood_group")
 .mean()
 .select(pl.col(pl.Float64))
 .pipe(debug, extra="summary")
)
# Out:
# before df.shape=(48895, 16)
# after df.shape=(48895, 17)
# summary df.shape=(5, 11)
# shape: (5, 11)
# ┌──────────┬──────────┬───────────┬────────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ id       ┆ host_id  ┆ latitude  ┆ longitude  ┆ … ┆ reviews_p ┆ calculate ┆ availabil ┆ temp      │
# │ ---      ┆ ---      ┆ ---       ┆ ---        ┆   ┆ er_month  ┆ d_host_li ┆ ity_365   ┆ ---       │
# │ f64      ┆ f64      ┆ f64       ┆ f64        ┆   ┆ ---       ┆ stings_co ┆ ---       ┆ f64       │
# │          ┆          ┆           ┆            ┆   ┆ f64       ┆ unt       ┆ f64       ┆           │
# │          ┆          ┆           ┆            ┆   ┆           ┆ ---       ┆           ┆           │
# │          ┆          ┆           ┆            ┆   ┆           ┆ f64       ┆           ┆           │
# ╞══════════╪══════════╪═══════════╪════════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 2.2735e7 ┆ 1.0561e8 ┆ 40.848305 ┆ -73.884552 ┆ … ┆ 1.837831  ┆ 2.233731  ┆ 165.75893 ┆ 55.450459 │
# │          ┆          ┆           ┆            ┆   ┆           ┆           ┆ 7         ┆           │
# │ 2.1597e7 ┆ 9.8534e7 ┆ 40.610225 ┆ -74.105805 ┆ … ┆ 1.87258   ┆ 2.319035  ┆ 199.67828 ┆ 55.873995 │
# │          ┆          ┆           ┆            ┆   ┆           ┆           ┆ 4         ┆           │
# │ 2.1755e7 ┆ 9.6157e7 ┆ 40.731531 ┆ -73.872775 ┆ … ┆ 1.9412    ┆ 4.060184  ┆ 144.45181 ┆ 55.913604 │
# │          ┆          ┆           ┆            ┆   ┆           ┆           ┆ 8         ┆           │
# │ 1.8257e7 ┆ 5.6715e7 ┆ 40.685036 ┆ -73.95119  ┆ … ┆ 1.283212  ┆ 2.284371  ┆ 100.23229 ┆ 56.169537 │
# │          ┆          ┆           ┆            ┆   ┆           ┆           ┆ 2         ┆           │
# │ 1.8775e7 ┆ 6.7831e7 ┆ 40.765062 ┆ -73.974607 ┆ … ┆ 1.272131  ┆ 12.79133  ┆ 111.97941 ┆ 55.908629 │
# └──────────┴──────────┴───────────┴────────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %% [markdown]
# ## Cleanup Columns

# %%
(ab
 .pipe(debug, extra='before')
 .merge(temps, on=['latitude', 'longitude']
       )
 .pipe(debug, extra='after') 
 .columns
)
# Out:
# before df.shape=(48895, 16)
# after df.shape=(48895, 17)
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'temp'],
#       dtype='object')

# %%
(ab_pl
 .pipe(debug, extra="before")
 .join(temps_pl, on=["latitude", "longitude"])
 .pipe(debug, extra="after")
 .columns
)
# Out:
# before df.shape=(48895, 16)
# after df.shape=(48895, 17)
# ['id',
#  'name',
#  'host_id',
#  'host_name',
#  'neighbourhood_group',
#  'neighbourhood',
#  'latitude',
#  'longitude',
#  'room_type',
#  'price',
#  'minimum_nights',
#  'number_of_reviews',
#  'last_review',
#  'reviews_per_month',
#  'calculated_host_listings_count',
#  'availability_365',
#  'temp']

# %%
# Explicitly list columns
(ab
 .pipe(debug, extra='before')
 .merge(temps, on=['latitude', 'longitude'])
 .pipe(debug, extra='after') 
 .loc[:, ['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
       'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
       'minimum_nights', 'number_of_reviews', 'last_review',
       'reviews_per_month', 'calculated_host_listings_count',
       'availability_365', 'temp']]
 .pipe(debug, extra='limit cols')  
)
# Out:
# before df.shape=(48895, 16)
# after df.shape=(48895, 17)
# limit cols df.shape=(48895, 17)
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
#            host_name neighbourhood_group       neighbourhood  latitude  \
# 0               John            Brooklyn          Kensington  40.64749
# 1           Jennifer           Manhattan             Midtown  40.75362
# 2          Elisabeth           Manhattan              Harlem  40.80902
# 3        LisaRoxanne            Brooklyn        Clinton Hill  40.68514
# 4              Laura           Manhattan         East Harlem  40.79851
# ...              ...                 ...                 ...       ...
# 48890        Sabrina            Brooklyn  Bedford-Stuyvesant  40.67853
# 48891        Marisol            Brooklyn            Bushwick  40.70184
# 48892  Ilgar & Aysel           Manhattan              Harlem  40.81475
# 48893            Taz           Manhattan      Hell's Kitchen  40.75751
# 48894     Christophe           Manhattan      Hell's Kitchen  40.76404
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# 0      -73.97237     Private room    149               1                  9
# 1      -73.98377  Entire home/apt    225               1                 45
# 2      -73.94190     Private room    150               3                  0
# 3      -73.95976  Entire home/apt     89               1                270
# 4      -73.94399  Entire home/apt     80              10                  9
# ...          ...              ...    ...             ...                ...
# 48890  -73.94995     Private room     70               2                  0
# 48891  -73.93317     Private room     40               4                  0
# 48892  -73.94867  Entire home/apt    115              10                  0
# 48893  -73.99112      Shared room     55               1                  0
# 48894  -73.98933     Private room     90               7                  0
#
#       last_review  reviews_per_month  calculated_host_listings_count  \
# 0      2018-10-19               0.21                               6
# 1      2019-05-21               0.38                               2
# 2            <NA>               <NA>                               1
# 3      2019-07-05               4.64                               1
# 4      2018-11-19                0.1                               1
# ...           ...                ...                             ...
# 48890        <NA>               <NA>                               2
# 48891        <NA>               <NA>                               2
# 48892        <NA>               <NA>                               1
# 48893        <NA>               <NA>                               6
# 48894        <NA>               <NA>                               1
#
#        availability_365  temp
# 0                   365  72.0
# 1                   355  57.0
# 2                   365  76.0
# 3                   194  24.0
# 4                     0  27.0
# ...                 ...   ...
# 48890                 9  76.0
# 48891                36  71.0
# 48892                27  44.0
# 48893                 2  73.0
# 48894                23  76.0
#
# [48895 rows x 17 columns]

# %%
# Explicitly list columns
(ab_pl
 .pipe(debug, extra="before")
 .join(temps_pl, on=["latitude", "longitude"])
 .pipe(debug, extra="after")
 [:, [
        "id",
        "name",
        "host_id",
        "host_name",
        "neighbourhood_group",
        "neighbourhood",
        "latitude",
        "longitude",
        "room_type",
        "price",
        "minimum_nights",
        "number_of_reviews",
        "last_review",
        "reviews_per_month",
        "calculated_host_listings_count",
        "availability_365",
        "temp",
        ],
    ]
 .pipe(debug, extra="limit cols")
)
# Out:
# before df.shape=(48895, 16)
# after df.shape=(48895, 17)
# limit cols df.shape=(48895, 17)
# shape: (48_895, 17)
# ┌──────────┬─────────────┬──────────┬────────────┬───┬────────────┬────────────┬────────────┬──────┐
# │ id       ┆ name        ┆ host_id  ┆ host_name  ┆ … ┆ reviews_pe ┆ calculated ┆ availabili ┆ temp │
# │ ---      ┆ ---         ┆ ---      ┆ ---        ┆   ┆ r_month    ┆ _host_list ┆ ty_365     ┆ ---  │
# │ i64      ┆ str         ┆ i64      ┆ str        ┆   ┆ ---        ┆ ings_count ┆ ---        ┆ f64  │
# │          ┆             ┆          ┆            ┆   ┆ f64        ┆ ---        ┆ i64        ┆      │
# │          ┆             ┆          ┆            ┆   ┆            ┆ i64        ┆            ┆      │
# ╞══════════╪═════════════╪══════════╪════════════╪═══╪════════════╪════════════╪════════════╪══════╡
# │ 2539     ┆ Clean &     ┆ 2787     ┆ John       ┆ … ┆ 0.21       ┆ 6          ┆ 365        ┆ 72.0 │
# │          ┆ quiet apt   ┆          ┆            ┆   ┆            ┆            ┆            ┆      │
# │          ┆ home by the ┆          ┆            ┆   ┆            ┆            ┆            ┆      │
# │          ┆ pa…         ┆          ┆            ┆   ┆            ┆            ┆            ┆      │
# │ 2595     ┆ Skylit      ┆ 2845     ┆ Jennifer   ┆ … ┆ 0.38       ┆ 2          ┆ 355        ┆ 57.0 │
# │          ┆ Midtown     ┆          ┆            ┆   ┆            ┆            ┆            ┆      │
# │          ┆ Castle      ┆          ┆            ┆   ┆            ┆            ┆            ┆      │
# │ 3647     ┆ THE VILLAGE ┆ 4632     ┆ Elisabeth  ┆ … ┆ null       ┆ 1          ┆ 365        ┆ 76.0 │
# │          ┆ OF HARLEM.. ┆          ┆            ┆   ┆            ┆            ┆            ┆      │
# │          ┆ ..NEW YOR…  ┆          ┆            ┆   ┆            ┆            ┆            ┆      │
# │ 3831     ┆ Cozy Entire ┆ 4869     ┆ LisaRoxann ┆ … ┆ 4.64       ┆ 1          ┆ 194        ┆ 24.0 │
# │          ┆ Floor of    ┆          ┆ e          ┆   ┆            ┆            ┆            ┆      │
# │          ┆ Brownstone  ┆          ┆            ┆   ┆            ┆            ┆            ┆      │
# │ …        ┆ …           ┆ …        ┆ …          ┆ … ┆ …          ┆ …          ┆ …          ┆ …    │
# │ 36485057 ┆ Affordable  ┆ 6570630  ┆ Marisol    ┆ … ┆ null       ┆ 2          ┆ 36         ┆ 71.0 │
# │          ┆ room in Bus ┆          ┆            ┆   ┆            ┆            ┆            ┆      │
# │          ┆ hwick/East… ┆          ┆            ┆   ┆            ┆            ┆            ┆      │
# │ 36485431 ┆ Sunny       ┆ 23492952 ┆ Ilgar &    ┆ … ┆ null       ┆ 1          ┆ 27         ┆ 44.0 │
# │          ┆ Studio at   ┆          ┆ Aysel      ┆   ┆            ┆            ┆            ┆      │
# │          ┆ Historical  ┆          ┆            ┆   ┆            ┆            ┆            ┆      │
# │          ┆ Neigh…      ┆          ┆            ┆   ┆            ┆            ┆            ┆      │
# │ 36485609 ┆ 43rd St.    ┆ 30985759 ┆ Taz        ┆ … ┆ null       ┆ 6          ┆ 2          ┆ 73.0 │
# │          ┆ Time        ┆          ┆            ┆   ┆            ┆            ┆            ┆      │
# │          ┆ Square-cozy ┆          ┆            ┆   ┆            ┆            ┆            ┆      │
# │          ┆ single…     ┆          ┆            ┆   ┆            ┆            ┆            ┆      │
# │ 36487245 ┆ Trendy      ┆ 68119814 ┆ Christophe ┆ … ┆ null       ┆ 1          ┆ 23         ┆ 76.0 │
# │          ┆ duplex in   ┆          ┆            ┆   ┆            ┆            ┆            ┆      │
# │          ┆ the very    ┆          ┆            ┆   ┆            ┆            ┆            ┆      │
# │          ┆ heart …     ┆          ┆            ┆   ┆            ┆            ┆            ┆      │
# └──────────┴─────────────┴──────────┴────────────┴───┴────────────┴────────────┴────────────┴──────┘

# %% [markdown]
# ## Export to Excel

# %%
with pd.ExcelWriter("data/airbnb.xlsx") as xls_out:
      xl = (ab
      .pipe(debug, extra='before')
      .merge(temps, on=['latitude', 'longitude'])
      .pipe(debug, extra='after') 
      .loc[:, ['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
            'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
            'minimum_nights', 'number_of_reviews', 'last_review',
            'reviews_per_month', 'calculated_host_listings_count',
            'availability_365', 'temp']]
      )

      xl.to_excel(xls_out, sheet_name='all')
      (xl
      .query('neighbourhood_group=="Brooklyn"')
      .to_excel(xls_out, sheet_name='Brooklyn')
      )
# Out:
# before df.shape=(48895, 16)
# after df.shape=(48895, 17)

# %%
from xlsxwriter import Workbook

with Workbook("data/airbnb_polars.xlsx") as xls_out:
      xl = (ab_pl
            .pipe(debug, extra='before')
            .join(temps_pl, on=['latitude', 'longitude'])
            .pipe(debug, extra='after') 
            [:, ['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
                  'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
                  'minimum_nights', 'number_of_reviews', 'last_review',
                  'reviews_per_month', 'calculated_host_listings_count',
                  'availability_365', 'temp']]
            )

      xl.write_excel(xls_out, worksheet='all')
      (xl
      .filter(pl.col('neighbourhood_group') == "Brooklyn")
      .write_excel(xls_out, worksheet='Brooklyn')
      )
# Out:
# before df.shape=(48895, 16)
# after df.shape=(48895, 17)
